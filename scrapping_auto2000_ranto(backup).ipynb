# %%
# !pip install google-search-results
# !pip install pandas
# Out:
# Requirement already satisfied: google-search-results in /usr/local/lib/python3.11/dist-packages (2.4.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from google-search-results) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->google-search-results) (2025.1.31)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from serpapi import GoogleSearch
from urllib.parse import *
import pandas as pd

params = {
  "engine": "google_maps",
  "q": "Toyota Auto2000",
  "ll": "@2.105857259955246, 99.82850985180268,14z",
  "type": "search",
  "api_key": "fed644f70c69d0dc4812218d3aca5facd7e4c092c539b7663c52575d3209e76a"
}

search = GoogleSearch(params)

lIdx = 0
lSum = 10
local_results = []

while lIdx <= lSum:
  results =search.get_dict()
  for Result in results["local_results"]:
    lIdx += 1

    if lIdx <= lSum:
      if Result ["reviews"]<200:
        lIdx += 1
        continue
      local_results.append({'Nama': Result["title"],
                            'data_id': Result["data_id"],
                            'total_reviews': Result["reviews"]});
    if "next" in results.get("serpapi_pagination",{}):
      search.params_dict.update(dict(parse_qsl(urlsplit(results.get("serpapi_pagination").get("next")).query)))
    else:
      break

# %%
for LR in local_results:
  print(LR)
# Out:
# {'Nama': 'Toyota Auto2000 Rantauprapat', 'data_id': '0x302da1ac3eab9c87:0x979ac3ca48e16c17', 'total_reviews': 241}
# {'Nama': 'Toyota Auto2000 Krakatau Medan', 'data_id': '0x30313218b0962b9f:0xca9a1dd3262081a8', 'total_reviews': 437}
# {'Nama': 'Toyota Auto2000 Medan Gatot Subroto', 'data_id': '0x30312e382266ab0b:0x5d7f19b5766fd368', 'total_reviews': 1554}
# {'Nama': 'Toyota Auto2000 Medan Binjai', 'data_id': '0x3031297318f78655:0x9442a1d44c7c1c27', 'total_reviews': 644}
# {'Nama': 'Toyota Auto2000 Sisingamangaraja', 'data_id': '0x3031304f7df093f1:0x5fd182e5fd5513b', 'total_reviews': 968}
# {'Nama': 'AUTO 2000 Marelan', 'data_id': '0x3036cd5d54715efb:0xd5d7796e14b91d76', 'total_reviews': 512}

# %%
# 2. Fetch reviews for the specific location (up to 200)
data = {'Nama_Showroom': [], 'name': [], 'rating': [], 'review': []}
review_params = {
    "engine": "google_maps_reviews",
    "data_id": "0x302da1ac3eab9c87:0x979ac3ca48e16c17",  # Use the extracted data_id
    "api_key" : "fed644f70c69d0dc4812218d3aca5facd7e4c092c539b7663c52575d3209e76a"
}

review_search = GoogleSearch(review_params)
reviews_fetched = 0
max_reviews = 200

while reviews_fetched < max_reviews:
    review_results = review_search.get_dict()
    if review_results.get("reviews"):  # Check if reviews are present in the current page
        for review in review_results["reviews"]:
            if reviews_fetched < max_reviews:  # Check review limit before adding
                data['Nama_Showroom'].append(place_name)  # Use the correct place name
                data['name'].append(review.get("user", {}).get("name", "Unknown User")) # Handle potential missing data
                data['rating'].append(review.get("rating")) # Handle potential missing data
                data['review'].append(review.get("snippet", "No Review")) # Handle potential missing data
                reviews_fetched += 1
            else:
                break  # Exit inner loop when review limit is hit
    else:
      print("No reviews found for this page or place.")
      break # Exit outer loop if no reviews

    if "next" in review_results.get("serpapi_pagination", {}):
        review_search.params_dict.update(dict(parse_qsl(urlsplit(review_results.get("serpapi_pagination").get("next")).query)))
    else:
        print("No more review pages found.")
        break  # Exit outer loop when no more pages

dfScrap = pd.DataFrame(data)
print(dfScrap) # Print the DataFrame for verification

# 3. Save to Excel
output_filename = f"{search_query}_reviews.xlsx"
dfScrap.to_excel(output_filename, index=False)
print(f"Reviews saved to {output_filename}")
# Out:
#                     Nama_Showroom                   name  rating  \
# 0    Toyota Auto2000 Rantauprapat       Akbar Dalimunthe     5.0
# 1    Toyota Auto2000 Rantauprapat        Habibi Nasution     5.0
# 2    Toyota Auto2000 Rantauprapat  Aslim Harapan Ritonga     5.0
# 3    Toyota Auto2000 Rantauprapat           Rakimen Raki     5.0
# 4    Toyota Auto2000 Rantauprapat           Bayu Anugrah     5.0
# ..                            ...                    ...     ...
# 195  Toyota Auto2000 Rantauprapat          David Tarigan     5.0
# 196  Toyota Auto2000 Rantauprapat             Daud Diven     5.0
# 197  Toyota Auto2000 Rantauprapat          Sarlan Sirait     5.0
# 198  Toyota Auto2000 Rantauprapat          Arkan Ritonga     5.0
# 199  Toyota Auto2000 Rantauprapat         Marhot Harahap     5.0
#
#                                                 review
# 0                                    Service excellent
# 1                                    SERVICE EXCELLENT
# 2                                      AUTO2000 ManTAF
# 3                                             The best
# 4                        Auto 2000 is the best forever
# ..                                                 ...
# 195                                             Mantap
# 196                                          No Review
# 197                                          No Review
# 198  Beli mobil di auto2000 rantauprapat sama sales...
# 199                         Prosesnya cepat dan tepat.
#
# [200 rows x 4 columns]
# Reviews saved to Toyota Auto2000 Rantauprapat_reviews.xlsx

# %%
data = {'Nama_Showroom':[],
        'name':[],
        'rating':[],
        'review':[]}

for LR in local_results:
  params = {
    "engine": "google_maps_reviews",
    "data_id": "",
    "api_key": "fed644f70c69d0dc4812218d3aca5facd7e4c092c539b7663c52575d3209e76a"
  }
  params["data_id"] = LR["data_id"]

  search = GoogleSearch(params)
  lIdx = 0
  lSum = 50

  while lIdx <= lSum:
    results = search.get_dict()

    for Result in results["reviews"]:
      lIdx += 1

      if lIdx <= lSum:
        data["Nama_Showroom"].append(LR["Nama"])
        data["name"].append(Result["user"]["name"])
        data["rating"].append(Result["rating"])
        data["review"].append(Result["snippet"])

      if "next" in results.get("serpapi_pagination",{}):
        search.params_dict.update(dict(parse_qsl(urlsplit(results.get("serpapi_pagination").get("next")).query)))
      else:
        break

review_original = data['review']
dfScrap = pd.DataFrame(data)
dfScrap
# Out:
#                       Nama_Showroom                   name  rating  \
# 0      Toyota Auto2000 Rantauprapat       Akbar Dalimunthe     5.0
# 1      Toyota Auto2000 Rantauprapat        Habibi Nasution     5.0
# 2      Toyota Auto2000 Rantauprapat  Aslim Harapan Ritonga     5.0
# 3      Toyota Auto2000 Rantauprapat           Rakimen Raki     5.0
# 4      Toyota Auto2000 Rantauprapat           Bayu Anugrah     5.0
# ..                              ...                    ...     ...
# 295  Toyota Auto2000 Tanjung Morawa           pakpak nduma     5.0
# 296  Toyota Auto2000 Tanjung Morawa    Juniarsih Juniarsih     5.0
# 297  Toyota Auto2000 Tanjung Morawa           Edi Zendrato     5.0
# 298  Toyota Auto2000 Tanjung Morawa      Rafli Raflitengku     5.0
# 299  Toyota Auto2000 Tanjung Morawa        Reza Herlambang     5.0
#
#                                                 review
# 0                                    Service excellent
# 1                                    SERVICE EXCELLENT
# 2                                      AUTO2000 ManTAF
# 3                                             The best
# 4                        Auto 2000 is the best forever
# ..                                                 ...
# 295  Servis dirumah lebih mudah dengan THS,bebas an...
# 296  Bersama wiraniaga auto2000 tj morawa afif toyo...
# 297  Pembelian di auto2000 Tanjung Morawa sangat me...
# 298  pelayanan okee, mekanik profesional dan kendar...
# 299  Belajar ttg mobil disini, kerjasama dr sekolah...
#
# [300 rows x 4 columns]

# %%
# Contoh data hanya untuk Auto2000 Rantauprapat
data = {
    'Nama_Showroom': ['Auto2000 Rantauprapat'] * 250,
    'name': [f'User{i}' for i in range(250)],
    'rating': [4] * 250,
    'review': [f'Review content {i}' for i in range(250)]
}

# Membuat DataFrame dari data
dfScrap = pd.DataFrame(data)

# Filter data untuk 'Auto2000 Rantauprapat' dan ambil 200 data pertama
filtered_df = dfScrap[dfScrap['Nama_Showroom'] == 'Auto2000 Rantauprapat'].head(200)

# Simpan hasil filter ke file .xlsx
output_path = 'auto2000_rantauprapat_reviews.xlsx'
filtered_df.to_excel(output_path, index=False, engine='openpyxl')

print(f"Data berhasil disimpan di {output_path}")
# Out:
# Data berhasil disimpan di auto2000_rantauprapat_reviews.xlsx

# %%
dfScrap.to_csv('data_review.csv')

# %%
from serpapi import GoogleSearch

params = {
    "engine": "google_maps_reviews",
    "data_id": "0x302da1ac3eab9c87:0x979ac3ca48e16c17",
    "api_key": "fed644f70c69d0dc4812218d3aca5facd7e4c092c539b7663c52575d3209e76a"
}

search = GoogleSearch(params)
results = search.get_dict()
reviews = results ["reviews"][1]["snippet"]

# %%
results
# Out:
# {'search_metadata': {'id': '67b6eabcbc26aadce337990b',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/960fcc8ebb68f235/67b6eabcbc26aadce337990b.json',
#   'created_at': '2025-02-20 08:41:32 UTC',
#   'processed_at': '2025-02-20 08:41:32 UTC',
#   'google_maps_reviews_url': 'https://www.google.com/maps/place/data=!4m7!3m6!1s0x302da1ac3eab9c87:0x979ac3ca48e16c17!5m2!4m1!1i2!9m1!1b1?hl=en&gl=',
#   'raw_html_file': 'https://serpapi.com/searches/960fcc8ebb68f235/67b6eabcbc26aadce337990b.html',
#   'prettify_html_file': 'https://serpapi.com/searches/960fcc8ebb68f235/67b6eabcbc26aadce337990b.prettify',
#   'total_time_taken': 0.4},
#  'search_parameters': {'engine': 'google_maps_reviews',
#   'data_id': '0x302da1ac3eab9c87:0x979ac3ca48e16c17',
#   'hl': 'en'},
#  'place_info': {'title': 'Toyota Auto2000 Rantauprapat',
#   'address': 'Jl. SM. Raja No.kel, Bakaran Batu, Kec. Rantau Sel., Kab. Labuhanbatu, Sumatera Utara 21421, Indonesia',
#   'rating': 4.7,
#   'reviews': 239,
#   'type': 'Toyota dealer'},
#  'topics': [{'keyword': 'public service', 'mentions': 33, 'id': '/m/04qkjn'},
#   {'keyword': 'process', 'mentions': 14, 'id': '/g/122q4xxl'},
#   {'keyword': 'discount', 'mentions': 4, 'id': '/m/01l_z9'},
#   {'keyword': 'MBA', 'mentions': 2, 'id': '/m/07s6fsf'},
#   {'keyword': 'supply', 'mentions': 2, 'id': '/m/080d1js'},
#   {'keyword': 'lunch', 'mentions': 2, 'id': '/m/0jfd5'},
#   {'keyword': 'space', 'mentions': 2, 'id': '/m/06wqb'}],
#  'reviews': [{'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnTUNBdnB2VVBnEAE!2m1!1s0x0:0x979ac3ca48e16c17!3m1!1s2@1:CIHM0ogKEICAgMCAvpvUPg%7CCgwI1a33vAYQsLS07wE%7C?hl=en-US',
#    'rating': 5.0,
#    'date': '2 weeks ago',
#    'iso_date': '2025-02-01T08:09:57Z',
#    'iso_date_of_last_edit': '2025-02-01T08:09:57Z',
#    'source': 'Google',
#    'review_id': 'ChZDSUhNMG9nS0VJQ0FnTUNBdnB2VVBnEAE',
#    'user': {'name': 'Akbar Dalimunthe',
#     'link': 'https://www.google.com/maps/contrib/101038255355836741730?hl=en-US',
#     'contributor_id': '101038255355836741730',
#     'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocLd5kZxE62sweSoaek4N3kmP1iAzsjNBpSnhTLqecFRQ2p9Bg=s120-c-rp-mo-br100',
#     'local_guide': True,
#     'reviews': 1,
#     'photos': 2},
#    'snippet': 'Service excellent',
#    'extracted_snippet': {'original': 'Service excellent'},
#    'likes': 0,
#    'response': {'date': '2 weeks ago',
#     'iso_date': '2025-02-01T08:53:13Z',
#     'iso_date_of_last_edit': '2025-02-01T08:53:13Z',
#     'snippet': 'Yth,\nBapak Akbar Dalimunthe\nTerima kasih telah memberikan ulasan baik dan berkunjung ke Auto2000 Rantauprapat menjadi bagian dari AutoFamily, kami menantikan kesempatan melayani AutoFamily kembali di Auto2000 Rantauprapat. Terima kasih\n\nHormat Kami,\nAuto2000 Rantauprapat',
#     'extracted_snippet': {'original': 'Yth,\nBapak Akbar Dalimunthe\nTerima kasih telah memberikan ulasan baik dan berkunjung ke Auto2000 Rantauprapat menjadi bagian dari AutoFamily, kami menantikan kesempatan melayani AutoFamily kembali di Auto2000 Rantauprapat. Terima kasih\n\nHormat Kami,\nAuto2000 Rantauprapat',
#      'translated': 'Dear,\nMr Akbar Dalimunthe\nThank you for giving a good review and visiting Auto2000 Rantauprapat as part of AutoFamily, we look forward to the opportunity to serve AutoFamily again at Auto2000 Rantauprapat. Thank You\n\nBest regards,\nAuto2000 Rantauprapat'}}},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURmX3NDV3JnRRAB!2m1!1s0x0:0x979ac3ca48e16c17!3m1!1s2@1:CIHM0ogKEICAgIDf_sCWrgE%7CCgsIgIryuwYQoM_pKw%7C?hl=en-US',
#    'rating': 5.0,
#    'date': 'a month ago',
#    'iso_date': '2025-01-07T01:36:00Z',
#    'iso_date_of_last_edit': '2025-01-07T01:36:00Z',
#    'source': 'Google',
#    'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURmX3NDV3JnRRAB',
#    'user': {'name': 'Habibi Nasution',
#     'link': 'https://www.google.com/maps/contrib/105876506756990762623?hl=en-US',
#     'contributor_id': '105876506756990762623',
#     'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocKkgD3m1ns4oZMXc3wHWwBmfTx13f8d61GlNhnojHh6tOb5Nw=s120-c-rp-mo-br100',
#     'local_guide': True,
#     'reviews': 1,
#     'photos': 0},
#    'snippet': 'SERVICE EXCELLENT',
#    'extracted_snippet': {'original': 'SERVICE EXCELLENT'},
#    'likes': 0,
#    'response': {'date': 'a month ago',
#     'iso_date': '2025-01-07T04:23:47Z',
#     'iso_date_of_last_edit': '2025-01-07T04:23:47Z',
#     'snippet': 'Yth,\nBapak Habibi Nasution\nTerima kasih atas kepercayaan Bapak kepada kami,semoga Bapak sehat dan sukses selalu.\nSalam AutoFamily🙏',
#     'extracted_snippet': {'original': 'Yth,\nBapak Habibi Nasution\nTerima kasih atas kepercayaan Bapak kepada kami,semoga Bapak sehat dan sukses selalu.\nSalam AutoFamily🙏',
#      'translated': 'Dear,\nMr Habibi Nasution\nThank you for your trust in us, we wish you good health and success.\nGreetings AutoFamily🙏'}}},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSURmdnIteFB3EAE!2m1!1s0x0:0x979ac3ca48e16c17!3m1!1s2@1:CIHM0ogKEICAgIDfvr-xPw%7CCgwI0YjyuwYQ4NXkogE%7C?hl=en-US',
#    'rating': 5.0,
#    'date': 'a month ago',
#    'iso_date': '2025-01-07T01:33:05Z',
#    'iso_date_of_last_edit': '2025-01-07T01:33:05Z',
#    'source': 'Google',
#    'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURmdnIteFB3EAE',
#    'user': {'name': 'Aslim Harapan Ritonga',
#     'link': 'https://www.google.com/maps/contrib/109681162459462689314?hl=en-US',
#     'contributor_id': '109681162459462689314',
#     'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocKQOZEuRvYgcHHmZaxuTo1ZfoSIY8nEytVV-66OPtABlKDN-w=s120-c-rp-mo-br100',
#     'reviews': 1,
#     'photos': 0},
#    'snippet': 'AUTO2000 ManTAF',
#    'extracted_snippet': {'original': 'AUTO2000 ManTAF'},
#    'likes': 0,
#    'response': {'date': 'a month ago',
#     'iso_date': '2025-01-07T04:37:13Z',
#     'iso_date_of_last_edit': '2025-01-07T04:37:13Z',
#     'snippet': 'Yth,\nBapak Aslim Harapan Ritonga\nTerima kasih telah memberikan ulasan kesan baik dan berkunjung di Auto2000 Rantauprapat menjadi bagian dari AutoFamily. Kami menantikan kesempatan untuk melayani AutoFamily kembali di Auto2000 Rantauprapat. Terima kasih\nHormat kami,\nAuto2000 Rantauprapat',
#     'extracted_snippet': {'original': 'Yth,\nBapak Aslim Harapan Ritonga\nTerima kasih telah memberikan ulasan kesan baik dan berkunjung di Auto2000 Rantauprapat menjadi bagian dari AutoFamily. Kami menantikan kesempatan untuk melayani AutoFamily kembali di Auto2000 Rantauprapat. Terima kasih\nHormat kami,\nAuto2000 Rantauprapat',
#      'translated': 'Dear,\nMr Aslim Harapan Ritonga\nThank you for giving a good review and visiting Auto2000 Rantauprapat to be part of the AutoFamily. We look forward to the opportunity to serve the AutoFamily again at Auto2000 Rantauprapat. Thank You\nBest regards,\nAuto2000 Rantauprapat'}}},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSURKNXBiaFVBEAE!2m1!1s0x0:0x979ac3ca48e16c17!3m1!1s2@1:CIHM0ogKEICAgIDJ5pbhUA%7CCgwIi7TOpQYQ8I_cvQM%7C?hl=en-US',
#    'rating': 5.0,
#    'date': 'a year ago',
#    'iso_date': '2023-07-16T07:19:39Z',
#    'iso_date_of_last_edit': '2023-07-16T07:19:39Z',
#    'source': 'Google',
#    'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURKNXBiaFVBEAE',
#    'user': {'name': 'Rakimen Raki',
#     'link': 'https://www.google.com/maps/contrib/109873333507929322599?hl=en-US',
#     'contributor_id': '109873333507929322599',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUx2aoX3AUahcma5yJnw9onsmHVQDKaDgx2H91yDSVugxLls9B3=s120-c-rp-mo-ba4-br100',
#     'local_guide': True,
#     'reviews': 86,
#     'photos': 39},
#    'snippet': 'The best',
#    'extracted_snippet': {'original': 'The best'},
#    'likes': 0},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURCOTktTmp3RRAB!2m1!1s0x0:0x979ac3ca48e16c17!3m1!1s2@1:CIHM0ogKEICAgIDB99-NjwE%7CCgwIsMzkngYQsOCL1gM%7C?hl=en-US',
#    'rating': 5.0,
#    'date': '2 years ago',
#    'iso_date': '2023-01-31T14:31:12Z',
#    'iso_date_of_last_edit': '2023-01-31T14:31:12Z',
#    'source': 'Google',
#    'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURCOTktTmp3RRAB',
#    'user': {'name': 'Bayu Anugrah',
#     'link': 'https://www.google.com/maps/contrib/111716978274344229473?hl=en-US',
#     'contributor_id': '111716978274344229473',
#     'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocJXh4RaulrYdV1wy1TToe8_EbLhxKyVtdFKu8HzTVA1MUdW5A=s120-c-rp-mo-br100',
#     'reviews': 1,
#     'photos': 0},
#    'snippet': 'Auto 2000 is the best forever',
#    'extracted_snippet': {'original': 'Auto 2000 is the best forever'},
#    'likes': 0},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURHaTYteDdBRRAB!2m1!1s0x0:0x979ac3ca48e16c17!3m1!1s2@1:CIHM0ogKEICAgIDGi6-x7AE%7CCgsIpOvHjQYQ6PC2DA%7C?hl=en-US',
#    'rating': 5.0,
#    'date': '3 years ago',
#    'iso_date': '2021-12-09T12:25:08Z',
#    'iso_date_of_last_edit': '2021-12-09T12:25:08Z',
#    'source': 'Google',
#    'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURHaTYteDdBRRAB',
#    'user': {'name': 'VISUAL STORE',
#     'link': 'https://www.google.com/maps/contrib/101542835732109863663?hl=en-US',
#     'contributor_id': '101542835732109863663',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUqqXVZ277HTtISibVbMrSaTu5W8HZ6QnZYNBDLam9zMtAiJ7lUCQ=s120-c-rp-mo-ba3-br100',
#     'local_guide': True,
#     'reviews': 15,
#     'photos': 42},
#    'snippet': 'Good',
#    'extracted_snippet': {'original': 'Good'},
#    'likes': 0},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChdDSUhNMG9nS0VJQ0FnSURnNnB2Y3dBRRAB!2m1!1s0x0:0x979ac3ca48e16c17!3m1!1s2@1:CIHM0ogKEICAgIDg6pvcwAE%7CCgwIgaC80gUQgMyR2wI%7C?hl=en-US',
#    'rating': 5.0,
#    'date': '7 years ago',
#    'iso_date': '2018-01-05T05:41:18Z',
#    'iso_date_of_last_edit': '2018-01-05T05:41:21Z',
#    'source': 'Google',
#    'review_id': 'ChdDSUhNMG9nS0VJQ0FnSURnNnB2Y3dBRRAB',
#    'user': {'name': 'Septo Sinambela',
#     'link': 'https://www.google.com/maps/contrib/110696726838622912212?hl=en-US',
#     'contributor_id': '110696726838622912212',
#     'thumbnail': 'https://lh3.googleusercontent.com/a/ACg8ocI9eYPtthU--uDWCXg2CTkT0e62LC-M6TJpzm-U0pbpUCP5pQ=s120-c-rp-mo-br100',
#     'local_guide': True,
#     'reviews': 9,
#     'photos': 0},
#    'snippet': 'Nice',
#    'extracted_snippet': {'original': 'Nice'},
#    'likes': 0},
#   {'link': 'https://www.google.com/maps/reviews/data=!4m8!14m7!1m6!2m5!1sChZDSUhNMG9nS0VJQ0FnSURDdDZhX09BEAE!2m1!1s0x0:0x979ac3ca48e16c17!3m1!1s2@1:CIHM0ogKEICAgIDCt6a_OA%7CCgwIja2g_AUQwNWwnwI%7C?hl=en-US',
#    'rating': 5.0,
#    'date': '4 years ago',
#    'iso_date': '2020-10-15T09:29:49Z',
#    'iso_date_of_last_edit': '2020-10-15T09:29:49Z',
#    'source': 'Google',
#    'review_id': 'ChZDSUhNMG9nS0VJQ0FnSURDdDZhX09BEAE',
#    'user': {'name': 'Hendra Simamora',
#     'link': 'https://www.google.com/maps/contrib/100317548016990050071?hl=en-US',
#     'contributor_id': '100317548016990050071',
#     'thumbnail': 'https://lh3.googleusercontent.com/a-/ALV-UjUxJRpLqqo043ZTSpiEt8R9W-ioFj5KdeOLhgoPiur0aLk1N94=s120-c-rp-mo-ba4-br100',
#     'local_guide': True,
#     'reviews': 158,
#     'photos': 95},
#    'snippet': 'Good',
#    'extracted_snippet': {'original': 'Good'},
#    'likes': 0}],
#  'serpapi_pagination': {'next': 'https://serpapi.com/search.json?data_id=0x302da1ac3eab9c87%3A0x979ac3ca48e16c17&engine=google_maps_reviews&hl=en&next_page_token=CAESBkVnSUlDQQ%3D%3D',
#   'next_page_token': 'CAESBkVnSUlDQQ=='}}

# %%
reviews
# Out:
# 'SERVICE EXCELLENT'

# %%
for i in range(10):
  rating = results["reviews"][i]["rating"]
  print(rating)
  review = results["reviews"][i]["snippet"]
  print(review)
# Out:
# 5.0
# Service excellent
# 5.0
# SERVICE EXCELLENT
# 5.0
# AUTO2000 ManTAF
# 5.0
# The best
# 5.0
# Auto 2000 is the best forever
# 5.0
# Good
# 5.0
# Nice
# 5.0
# Good
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-3eef5a0b8d39> in <cell line: 0>()
#       1 for i in range(10):
# ----> 2   rating = results["reviews"][i]["rating"]
#       3   print(rating)
#       4   review = results["reviews"][i]["snippet"]
#       5   print(review)
#
# IndexError: list index out of range
